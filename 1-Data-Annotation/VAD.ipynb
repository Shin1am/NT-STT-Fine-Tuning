# %%
#install library
# !pip install torch torchaudio transformers librosa torchcodec soundfile
# Out:
# Requirement already satisfied: torch in /Users/shin1am/mambaforge/lib/python3.10/site-packages (2.10.0)
# Requirement already satisfied: torchaudio in /Users/shin1am/mambaforge/lib/python3.10/site-packages (2.10.0)
# Requirement already satisfied: transformers in /Users/shin1am/mambaforge/lib/python3.10/site-packages (5.1.0)
# Requirement already satisfied: librosa in /Users/shin1am/mambaforge/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: torchcodec in /Users/shin1am/mambaforge/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: soundfile in /Users/shin1am/mambaforge/lib/python3.10/site-packages (0.13.1)
# Requirement already satisfied: filelock in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from torch) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from transformers) (1.4.1)
# Requirement already satisfied: numpy>=1.17 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from transformers) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (0.63.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (1.7.2)
# Requirement already satisfied: joblib>=1.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: pooch>=1.1 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from librosa) (1.1.2)
# Requirement already satisfied: cffi>=1.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.28.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from typer-slim->transformers) (8.3.1)
# Requirement already satisfied: anyio in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.4)
# Requirement already satisfied: h11>=0.16 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (1.26.14)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/shin1am/mambaforge/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.2.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
import librosa
from transformers import pipeline
import json
import os
import soundfile as sf

# %%
#CONFIGURATION

AUDIO_DIR = "./audio_data"
OUTPUT_DIR = "./audio_data/dataset1"
OUTPUT_JSON = "ls_predictions.json"

DEVICE = 0 if torch.cuda.is_available() else -1

# %%
#Load VAD MODEL

vad_model, utils = torch.hub.load(repo_or_dir='snakers4/silero-vad', model='silero_vad')
(get_speech_timestamps, _, read_audio, _, _) = utils
# Out:
# Using cache found in /Users/shin1am/.cache/torch/hub/snakers4_silero-vad_master

# %%
#set ASR pipeline using thonburian whisper


asr_pipe = pipeline(
    task="automatic-speech-recognition",
    model="biodatlab/whisper-th-medium-combined", 
    chunk_length_s=30,
    device=DEVICE
)
# Out:
# Loading weights: 100%|██████████| 948/948 [00:00<00:00, 1257.85it/s, Materializing param=proj_out.weight]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to proj_out.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Using `chunk_length_s` is very experimental with seq2seq models. The results will not necessarily be entirely accurate and will have caveats. More information: https://github.com/huggingface/transformers/pull/20104. Ignore this warning with pipeline(..., ignore_warning=True). To use Whisper for long-form transcription, use rather the model's `generate` method directly as the model relies on it's own chunking mechanism (cf. Whisper original paper, section 3.8. Long-form Transcription).

# %%
#Create a function for process the audio
def process_audio_to_ls():

    if not os.path.exists(AUDIO_DIR):
        print(f"Error: Folder {AUDIO_DIR} not found.")
        return
    
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)
    

    audio_files = [f for f in os.listdir(AUDIO_DIR) if f.endswith(('.wav', '.mp3'))]
    all_tasks = []

    for file_name in audio_files:
        print(f"Processing: {file_name}")
        path = os.path.join(AUDIO_DIR, file_name)
    
        wav = read_audio(path, sampling_rate=16000)
        # Get timestamps in seconds
        speech_timestamps = get_speech_timestamps(wav, vad_model, sampling_rate=16000, return_seconds=True)
    
    
        # 3. RUN ASR ON EACH SEGMENT
        full_audio, sr = librosa.load(path, sr=16000)
    
        for i, segment in enumerate(speech_timestamps):
            start, end = segment['start'], segment['end']
        
            # Extract the audio chunk for this segment
            start_sample = int(start * sr)
            end_sample = int(end * sr)
            audio_chunk = full_audio[start_sample:end_sample]

            # --- NEW: SAVE THE CUT ---
            # Create a unique filename for the segment
            segment_filename = f"{os.path.splitext(file_name)[0]}_cut_{i}.wav"
            segment_path = os.path.join(OUTPUT_DIR, segment_filename)
            
            # Save using soundfile
            sf.write(segment_path, audio_chunk, sr)
            # -------------------------
        
            # Transcribe chunk
            transcription = asr_pipe(audio_chunk)["text"]


            #Create the Label Studio task
            task = {
                "data": {
                    "audio": f"/data/local-files/?d=files/dataset1/{segment_filename}"
                },
                "predictions": [{
                    "model_version": "VAD-Whisper-Thai-v1",
                    "result": [
                        {
                            "from_name": "transcription",
                            "to_name": "audio",
                            "type": "textarea",
                            "value": { "text": [transcription] }
                        }
                    ]
                }]
            }

            all_tasks.append(task)
            
    return all_tasks

# %%
final_task = process_audio_to_ls()

with open(OUTPUT_JSON, "w", encoding="utf-8") as f:
    json.dump([final_task], f, ensure_ascii=False, indent=4)
# Out:
# Processing: Example1.mp3
# Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# Transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English. This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`. See https://github.com/huggingface/transformers/pull/28687 for more details.
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
